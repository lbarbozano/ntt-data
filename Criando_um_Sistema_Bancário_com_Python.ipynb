# %%
class ContaBancaria:
    def _init_(self):
        self.saldo = 0.0
        self.extrato = []

    def deposito(self, valor):
        if valor <= 0:
            print("O valor do depósito deve ser maior que zero.")
            return
        self.saldo += valor
        self.extrato.append(f"Depósito: R$ {valor:.2f}")
        print(f"Depósito realizado com sucesso! Novo saldo: R$ {self.saldo:.2f}")

    def saque(self, valor):
        if valor <= 0:
            print("O valor do saque deve ser maior que zero.")
            return
        if valor > self.saldo:
            print("Saldo insuficiente para realizar o saque.")
            return
        self.saldo -= valor
        self.extrato.append(f"Saque: R$ {valor:.2f}")
        print(f"Saque realizado com sucesso! Novo saldo: R$ {self.saldo:.2f}")

    def extrato_bancario(self):
        print("\n--- Extrato Bancário ---")
        for operacao in self.extrato:
            print(operacao)
        print(f"Saldo final: R$ {self.saldo:.2f}\n")

def main():
    conta = ContaBancaria()

    while True:
        print("Selecione a operação desejada:")
        print("1: Depósito")
        print("2: Saque")
        print("3: Extrato")
        print("0: Sair")

        opcao = input("Digite a opção: ")

        if opcao == '1':
            try:
                valor = float(input("Digite o valor do depósito: R$ "))
                conta.deposito(valor)
            except ValueError:
                print("Entrada inválida! Por favor, digite um número.")
        elif opcao == '2':
            try:
                valor = float(input("Digite o valor do saque: R$ "))
                conta.saque(valor)
            except ValueError:
                print("Entrada inválida! Por favor, digite um número.")
        elif opcao == '3':
            conta.extrato_bancario()
        elif opcao == '0':
            print("Saindo do sistema... Até logo!")
            break
        else:
            print("Opção inválida! Tente novamente.")
class ContaBancaria:
    def __init__(self):
        self.saldo = 0.0
        self.extrato = []

    def deposito(self, valor):
        if valor <= 0:
            print("O valor do depósito deve ser maior que zero.")
            return
        self.saldo += valor
        self.extrato.append(f"Depósito: R$ {valor:.2f}")
        print(f"Depósito realizado com sucesso! Novo saldo: R$ {self.saldo:.2f}")

    def saque(self, valor):
        if valor <= 0:
            print("O valor do saque deve ser maior que zero.")
            return
        if valor > self.saldo:
            print("Saldo insuficiente para realizar o saque.")
            return
        self.saldo -= valor
        self.extrato.append(f"Saque: R$ {valor:.2f}")
        print(f"Saque realizado com sucesso! Novo saldo: R$ {self.saldo:.2f}")

    def extrato_bancario(self):
        print("\n--- Extrato Bancário ---")
        for operacao in self.extrato:
            print(operacao)
        print(f"Saldo final: R$ {self.saldo:.2f}\n")

def main():
    conta = ContaBancaria()

    while True:
        print("Selecione a operação desejada:")
        print("1: Depósito")
        print("2: Saque")
        print("3: Extrato")
        print("0: Sair")

        opcao = input("Digite a opção: ")

        if opcao == '1':
            try:
                valor = float(input("Digite o valor do depósito: R$ "))
                conta.deposito(valor)
            except ValueError:
                print("Entrada inválida! Por favor, digite um número.")
        elif opcao == '2':
            try:
                valor = float(input("Digite o valor do saque: R$ "))
                conta.saque(valor)
            except ValueError:
                print("Entrada inválida! Por favor, digite um número.")
        elif opcao == '3':
            conta.extrato_bancario()
        elif opcao == '0':
            print("Saindo do sistema... Até logo!")
            break
        else:
            print("Opção inválida! Tente novamente.")

if __name__ == "__main__":
    main()
# Out:
# Selecione a operação desejada:
# 1: Depósito
# 2: Saque
# 3: Extrato
# 0: Sair
# Digite a opção: 1
# Digite o valor do depósito: R$ 5000
# Depósito realizado com sucesso! Novo saldo: R$ 5000.00
# Selecione a operação desejada:
# 1: Depósito
# 2: Saque
# 3: Extrato
# 0: Sair
# Digite a opção: 2
# Digite o valor do saque: R$ 6000
# Saldo insuficiente para realizar o saque.
# Selecione a operação desejada:
# 1: Depósito
# 2: Saque
# 3: Extrato
# 0: Sair
# Digite a opção: 2
# Digite o valor do saque: R$ 3000
# Saque realizado com sucesso! Novo saldo: R$ 2000.00
# Selecione a operação desejada:
# 1: Depósito
# 2: Saque
# 3: Extrato
# 0: Sair
# Digite a opção: 3
#
# --- Extrato Bancário ---
# Depósito: R$ 5000.00
# Saque: R$ 3000.00
# Saldo final: R$ 2000.00
#
# Selecione a operação desejada:
# 1: Depósito
# 2: Saque
# 3: Extrato
# 0: Sair
# Digite a opção: 0
# Saindo do sistema... Até logo!
